# %%
import numpy as np

# %%
arr = np.random.rand(5, 5)

# %%
arr
# Out:
# array([[0.42324024, 0.67409315, 0.93290223, 0.60601314, 0.11075385],
#        [0.38433457, 0.82733614, 0.37897615, 0.19475014, 0.86235845],
#        [0.55616065, 0.41089851, 0.22867528, 0.01567323, 0.51721648],
#        [0.4704557 , 0.92002937, 0.18305147, 0.26238963, 0.4666114 ],
#        [0.20393779, 0.17799486, 0.39007551, 0.86010599, 0.21178207]])

# %%
arr.shape
# Out:
# (5, 5)

# %%
arr.dtype
# Out:
# dtype('float64')

# %%
arr[:4] #cut to 4th index of row i.e. 3.
# Out:
# array([[0.42324024, 0.67409315, 0.93290223, 0.60601314, 0.11075385],
#        [0.38433457, 0.82733614, 0.37897615, 0.19475014, 0.86235845],
#        [0.55616065, 0.41089851, 0.22867528, 0.01567323, 0.51721648],
#        [0.4704557 , 0.92002937, 0.18305147, 0.26238963, 0.4666114 ]])

# %%
arr[:4].shape
# Out:
# (4, 5)

# %%
arr[:, :4] #cutting column
# Out:
# array([[0.42324024, 0.67409315, 0.93290223, 0.60601314],
#        [0.38433457, 0.82733614, 0.37897615, 0.19475014],
#        [0.55616065, 0.41089851, 0.22867528, 0.01567323],
#        [0.4704557 , 0.92002937, 0.18305147, 0.26238963],
#        [0.20393779, 0.17799486, 0.39007551, 0.86010599]])

# %%
arr[:-1] #cutting the last row
# Out:
# array([[0.42324024, 0.67409315, 0.93290223, 0.60601314, 0.11075385],
#        [0.38433457, 0.82733614, 0.37897615, 0.19475014, 0.86235845],
#        [0.55616065, 0.41089851, 0.22867528, 0.01567323, 0.51721648],
#        [0.4704557 , 0.92002937, 0.18305147, 0.26238963, 0.4666114 ]])

# %%
inp_arr = np.random.randint(5, size=(7,8))

# %%
inp_arr
# Out:
# array([[3, 1, 0, 4, 0, 1, 2, 2],
#        [0, 1, 4, 1, 3, 4, 1, 4],
#        [1, 1, 3, 1, 2, 1, 0, 3],
#        [1, 3, 3, 1, 2, 2, 0, 2],
#        [0, 1, 4, 2, 1, 3, 3, 3],
#        [2, 2, 0, 4, 4, 3, 1, 0],
#        [0, 4, 0, 0, 1, 2, 3, 4]], dtype=int32)

# %%
ia0 = inp_arr[0]

# %%
ia0
# Out:
# array([3, 1, 0, 4, 0, 1, 2, 2], dtype=int32)

# %%
ia0_is012 = (ia0 == 0 )| (ia0 == 1) | (ia0 == 2) #detect specific values via Boolean validation

# %%
ia0_is012
# Out:
# array([False,  True,  True, False,  True,  True,  True,  True])

# %%
ia0[ia0_is012] #mask the array to obtain those specific values only
# Out:
# array([1, 0, 0, 1, 2, 2], dtype=int32)
