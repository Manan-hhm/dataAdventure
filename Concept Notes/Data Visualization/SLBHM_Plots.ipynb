# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
churn = pd.read_csv("Datasets/Churn_Modelling.csv")

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
churn.sample(1000).plot.scatter(x="Age", y="CreditScore")  #Using Pandas. sample(1000) reduces points for clarity
# Out:
# <Axes: xlabel='Age', ylabel='CreditScore'>

# %%
plt.scatter(x=churn["Age"], y=churn["CreditScore"])
plt.xlabel("Age")
plt.ylabel("Credit Score")
# Out:
# Text(0, 0.5, 'Credit Score')

# %%
sns.scatterplot(data=churn, x="Age", y="CreditScore")
# Out:
# <Axes: xlabel='Age', ylabel='CreditScore'>

# %%
#average credit score and salary by age
churn_age_cs_sal = churn.groupby('Age')[['CreditScore', 'EstimatedSalary']].mean().reset_index()

# %%
churn_age_cs_sal
# Out:
#     Age  CreditScore  EstimatedSalary
# 0    18   686.681818     85102.389545
# 1    19   665.629630     97734.100370
# 2    20   665.050000     97705.542000
# 3    21   647.283019    102536.673774
# 4    22   636.547619     98321.615476
# ..  ...          ...              ...
# 65   83   678.000000     92934.410000
# 66   84   472.500000    187360.250000
# 67   85   787.000000    116537.960000
# 68   88   513.000000     52952.240000
# 69   92   729.000000    115000.410000
#
# [70 rows x 3 columns]

# %%
churn_age_cs_sal.plot.line(x = 'Age', y = 'CreditScore')         #Using Pandas to plot line
# Out:
# <Axes: xlabel='Age'>

# %%
plt.plot(churn_age_cs_sal["Age"],churn_age_cs_sal["CreditScore"])        #Using Matplotlib to plot line

# %%
sns.lineplot(data=churn_age_cs_sal, x="Age", y="CreditScore")          #Using seaborn to plot line
# Out:
# <Axes: xlabel='Age', ylabel='CreditScore'>

# %%
churnSalGen = churn.groupby("Gender")[["EstimatedSalary","CreditScore"]].mean().reset_index()

# %%
# bar plot using Pandas, use ploth method to plot horizontally
churnSalGen.plot.bar(x="Gender", y="EstimatedSalary")
# Out:
# <Axes: xlabel='Gender'>

# %%
# Bar plot using matplotlib, use barh method to plot horizontally
plt.bar(churnSalGen["Gender"], churnSalGen["EstimatedSalary"])
# Out:
# <BarContainer object of 2 artists>

# %%
#Barplot using seaborn, swap axes to plot horizontally
sns.barplot(data=churnSalGen, x="Gender", y="EstimatedSalary")
# Out:
# <Axes: xlabel='Gender', ylabel='EstimatedSalary'>

# %%
#histogram using pandas, gender is a category => No binning required
churn["Gender"].hist()
# Out:
# <Axes: >

# %%
#Pandas will need an additional statement with method value_counts() to give output number
churn["Gender"].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
#histogram using matplotlib. Plot as well as Store values in variables to show output in numbers
values, x, _ = plt.hist(churn["Gender"])

# %%
#get count values for histogram categories
values
# Out:
# array([4543.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#        5457.])

# %%
#Binning using Pandas
churn["EstimatedSalary"].hist()
# Out:
# <Axes: >

# %%
#Binning using matplotlib. Plot as well as Store values in variables to show output in numbers
values, x, _ = plt.hist(churn["EstimatedSalary"])

# %%
#Use variable x to see binning distribution
x
# Out:
# array([1.1580000e+01, 2.0009670e+04, 4.0007760e+04, 6.0005850e+04,
#        8.0003940e+04, 1.0000203e+05, 1.2000012e+05, 1.3999821e+05,
#        1.5999630e+05, 1.7999439e+05, 1.9999248e+05])

# %%
#use values to get count fot each bin
values
# Out:
# array([ 987.,  968., 1006., 1027., 1002., 1027., 1007.,  982., 1009.,
#         985.])

# %%
#default bins for Pandas and matplotlib = 10. pass parameter for bins to change it.
churn["EstimatedSalary"].hist(bins=100)
# Out:
# <Axes: >

# %%
values, x, _ = plt.hist(churn["EstimatedSalary"], bins=100)

# %%
x
# Out:
# array([1.15800000e+01, 2.01138900e+03, 4.01119800e+03, 6.01100700e+03,
#        8.01081600e+03, 1.00106250e+04, 1.20104340e+04, 1.40102430e+04,
#        1.60100520e+04, 1.80098610e+04, 2.00096700e+04, 2.20094790e+04,
#        2.40092880e+04, 2.60090970e+04, 2.80089060e+04, 3.00087150e+04,
#        3.20085240e+04, 3.40083330e+04, 3.60081420e+04, 3.80079510e+04,
#        4.00077600e+04, 4.20075690e+04, 4.40073780e+04, 4.60071870e+04,
#        4.80069960e+04, 5.00068050e+04, 5.20066140e+04, 5.40064230e+04,
#        5.60062320e+04, 5.80060410e+04, 6.00058500e+04, 6.20056590e+04,
#        6.40054680e+04, 6.60052770e+04, 6.80050860e+04, 7.00048950e+04,
#        7.20047040e+04, 7.40045130e+04, 7.60043220e+04, 7.80041310e+04,
#        8.00039400e+04, 8.20037490e+04, 8.40035580e+04, 8.60033670e+04,
#        8.80031760e+04, 9.00029850e+04, 9.20027940e+04, 9.40026030e+04,
#        9.60024120e+04, 9.80022210e+04, 1.00002030e+05, 1.02001839e+05,
# ...

# %%
values
# Out:
# array([109., 104.,  99.,  85., 112.,  89., 106.,  90.,  97.,  96.,  93.,
#         91.,  96., 117.,  94.,  94.,  95., 101., 102.,  85., 104.,  92.,
#         90., 105., 107.,  95.,  96., 113., 111.,  93., 107., 103., 110.,
#         99.,  88.,  96., 100., 101., 107., 116.,  98., 103., 109.,  95.,
#        105.,  99., 122.,  98.,  87.,  86., 111., 121., 108.,  94., 102.,
#         86.,  99., 103., 104.,  99., 108.,  97., 101., 110.,  89., 109.,
#         96.,  95., 105.,  97., 105., 107.,  95., 112., 102.,  87.,  95.,
#         78.,  89., 112.,  89., 101.,  85., 109.,  94., 103., 107., 103.,
#        113., 105.,  94., 105.,  89.,  95.,  92., 101., 100.,  93., 108.,
#        108.])

# %%
#gives labels and outlines bars unlike pandas and matplotlib
sns.histplot(data=churn, x="EstimatedSalary", bins=100)
#save figure using matplotlib methods (seaborn also uses matplotlib internally) 
plt.savefig("histSal.svg")   # .svg is the most recommended format. It is infinitely zoomable

# %%
#Average credit score and salary by age as well as gender
churn_age_cs_sal_g = churn.groupby(["Age","Gender"])[['CreditScore', 'EstimatedSalary']].mean().reset_index()

# %%
#Line plot for above dataset using seaborn
sns.lineplot(data=churn_age_cs_sal_g, x="Age", y="CreditScore", hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='CreditScore'>

# %%
#Plot separately using seaborn
sns.relplot(data=churn_age_cs_sal_g, x="Age", y="CreditScore", row="Gender")

# %%
sns.relplot(data=churn_age_cs_sal_g, x="Age", y="CreditScore", col="Gender", kind="line")

# %%
sns.relplot(data=churn, x="Age", y="CreditScore", row="Gender", col="HasCrCard")

# %%
#using Pandas/Matplotlib for multiple figures
fig, axes = plt.subplots(2, 1)
for i,g in enumerate(["Male", "Female"]):
    churn_age_cs_sal_g[churn_age_cs_sal_g["Gender"] == g].plot.line(x="Age", y="CreditScore",ax=axes[i])

# %%
sns.pairplot(data=churn[["Age","HasCrCard","CreditScore"]])
