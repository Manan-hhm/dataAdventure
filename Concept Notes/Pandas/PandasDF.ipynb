# %%
import pandas as pd
import numpy as np

# %%
#Create a Numpy array
a = [[1,2], [3,4]]
np.array(a)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#Create a DataFrame
pd.DataFrame(a)
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
#Labelled list (of python dictionaries)
df = pd.DataFrame([{"math": 1, "science": 2, "Name": "A"}, {"math": 3, "science": 4, "Name": "B"}])
df
# Out:
#    math  science Name
# 0     1        2    A
# 1     3        4    B

# %%
#Score of all students for math /// Math series
df["math"]
# Out:
# 0    1
# 1    3
# Name: math, dtype: int64

# %%
type(df["math"])  #This is a series
# Out:
# pandas.Series

# %%
type(df)          #This is a DataFrame. DataFrame is made up of series
# Out:
# pandas.DataFrame

# %%
#Know no. of rows and columns and more information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   math     2 non-null      int64
#  1   science  2 non-null      int64
#  2   Name     2 non-null      str
# dtypes: int64(2), str(1)
# memory usage: 180.0 bytes

# %%
df.head(1)      #To show top few entries of a DataFrame, by default top 5
# Out:
#    math  science Name
# 0     1        2    A

# %%
df.tail(1)      #To show bottom few entries of a DataFrame, by default bottom 5
# Out:
#    math  science Name
# 1     3        4    B
