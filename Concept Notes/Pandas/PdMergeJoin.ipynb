# %%
import pandas as pd

# %%
countries_covid = pd.read_csv("Covid-19/countries-aggregated.csv")

# %%
countries_ref = pd.read_csv("Covid-19/reference.csv")

# %%
countries_ref.head()         #Data with missing values can be seen
# Out:
#    UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region       Lat  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN    Afghanistan  33.93911
# 1    8   AL  ALB    8.0   NaN    NaN            NaN        Albania  41.15330
# 2   10   AQ  ATA   10.0   NaN    NaN            NaN     Antarctica -71.94990
# 3   12   DZ  DZA   12.0   NaN    NaN            NaN        Algeria  28.03390
# 4   20   AD  AND   20.0   NaN    NaN            NaN        Andorra  42.50630
#
#        Long_ Combined_Key  Population
# 0  67.709953  Afghanistan  38928341.0
# 1  20.168300      Albania   2877800.0
# 2  23.347000   Antarctica         NaN
# 3   1.659600      Algeria  43851043.0
# 4   1.521800      Andorra     77265.0

# %%
countries_ref             #Complete data which shows columns which have both missing and filled values
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0            4   AF  AFG    4.0      NaN         NaN            NaN
# 1            8   AL  ALB    8.0      NaN         NaN            NaN
# 2           10   AQ  ATA   10.0      NaN         NaN            NaN
# 3           12   DZ  DZA   12.0      NaN         NaN            NaN
# 4           20   AD  AND   20.0      NaN         NaN            NaN
# ...        ...  ...  ...    ...      ...         ...            ...
# 4311  84056037   US  USA  840.0  56037.0  Sweetwater        Wyoming
# 4312  84056039   US  USA  840.0  56039.0       Teton        Wyoming
# 4313  84056041   US  USA  840.0  56041.0       Uinta        Wyoming
# 4314  84056043   US  USA  840.0  56043.0    Washakie        Wyoming
# 4315  84056045   US  USA  840.0  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_             Combined_Key  \
# 0       Afghanistan  33.939110   67.709953              Afghanistan
# ...

# %%
countries_ref_no_states = countries_ref[countries_ref["Province_State"].isna()]

# %%
countries_covid
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460
# 161564  2022-04-13     Zimbabwe     247160          0    5460
# 161565  2022-04-14     Zimbabwe     247208          0    5462
# 161566  2022-04-15     Zimbabwe     247237          0    5462
# 161567  2022-04-16     Zimbabwe     247237          0    5462
#
# [161568 rows x 5 columns]

# %%
countries_ref_no_states = countries_ref_no_states.rename(columns={"Country_Region": "Country"})

# %%
countries_ref_no_states
# Out:
#      UID iso2 iso3  code3  FIPS Admin2 Province_State      Country        Lat  \
# 0      4   AF  AFG    4.0   NaN    NaN            NaN  Afghanistan  33.939110
# 1      8   AL  ALB    8.0   NaN    NaN            NaN      Albania  41.153300
# 2     10   AQ  ATA   10.0   NaN    NaN            NaN   Antarctica -71.949900
# 3     12   DZ  DZA   12.0   NaN    NaN            NaN      Algeria  28.033900
# 4     20   AD  AND   20.0   NaN    NaN            NaN      Andorra  42.506300
# ..   ...  ...  ...    ...   ...    ...            ...          ...        ...
# 848  716   ZW  ZWE  716.0   NaN    NaN            NaN     Zimbabwe -19.015438
# 849   36   AU  AUS   36.0   NaN    NaN            NaN    Australia -25.000000
# 858  124   CA  CAN  124.0   NaN    NaN            NaN       Canada  60.000000
# 875  156   CN  CHN  156.0   NaN    NaN            NaN        China  35.861700
# 910  840   US  USA  840.0   NaN    NaN            NaN           US  40.000000
#
# ...

# %%
countries_covid.merge(countries_ref_no_states[["Population", "Country"]])
# Out:
#               Date      Country  Confirmed  Recovered  Deaths  Population
# 0       2020-01-22  Afghanistan          0          0       0  38928341.0
# 1       2020-01-23  Afghanistan          0          0       0  38928341.0
# 2       2020-01-24  Afghanistan          0          0       0  38928341.0
# 3       2020-01-25  Afghanistan          0          0       0  38928341.0
# 4       2020-01-26  Afghanistan          0          0       0  38928341.0
# ...            ...          ...        ...        ...     ...         ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460  14862927.0
# 161564  2022-04-13     Zimbabwe     247160          0    5460  14862927.0
# 161565  2022-04-14     Zimbabwe     247208          0    5462  14862927.0
# 161566  2022-04-15     Zimbabwe     247237          0    5462  14862927.0
# 161567  2022-04-16     Zimbabwe     247237          0    5462  14862927.0
#
# [161568 rows x 6 columns]

# %%
countries_ref
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0            4   AF  AFG    4.0      NaN         NaN            NaN
# 1            8   AL  ALB    8.0      NaN         NaN            NaN
# 2           10   AQ  ATA   10.0      NaN         NaN            NaN
# 3           12   DZ  DZA   12.0      NaN         NaN            NaN
# 4           20   AD  AND   20.0      NaN         NaN            NaN
# ...        ...  ...  ...    ...      ...         ...            ...
# 4311  84056037   US  USA  840.0  56037.0  Sweetwater        Wyoming
# 4312  84056039   US  USA  840.0  56039.0       Teton        Wyoming
# 4313  84056041   US  USA  840.0  56041.0       Uinta        Wyoming
# 4314  84056043   US  USA  840.0  56043.0    Washakie        Wyoming
# 4315  84056045   US  USA  840.0  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_             Combined_Key  \
# 0       Afghanistan  33.939110   67.709953              Afghanistan
# ...

# %%
countries_covid.merge(countries_ref[["Population", "Country_Region"]].rename(columns={"Country_Region": "Country"}))
# Out:
#                Date      Country  Confirmed  Recovered  Deaths  Population
# 0        2020-01-22  Afghanistan          0          0       0  38928341.0
# 1        2020-01-23  Afghanistan          0          0       0  38928341.0
# 2        2020-01-24  Afghanistan          0          0       0  38928341.0
# 3        2020-01-25  Afghanistan          0          0       0  38928341.0
# 4        2020-01-26  Afghanistan          0          0       0  38928341.0
# ...             ...          ...        ...        ...     ...         ...
# 3521035  2022-04-12     Zimbabwe     247094          0    5460  14862927.0
# 3521036  2022-04-13     Zimbabwe     247160          0    5460  14862927.0
# 3521037  2022-04-14     Zimbabwe     247208          0    5462  14862927.0
# 3521038  2022-04-15     Zimbabwe     247237          0    5462  14862927.0
# 3521039  2022-04-16     Zimbabwe     247237          0    5462  14862927.0
#
# [3521040 rows x 6 columns]

# %%
countries_covid_sample = pd.read_csv("Covid-19/countries-aggregated-sample.csv")
countries_covid_sample
# Out:
#              Date      Country  Confirmed  Recovered  Deaths
# 0      2020-01-22  Afghanistan          0          0       0
# 1      2020-01-23  Afghanistan          0          0       0
# 2      2020-01-24  Afghanistan          0          0       0
# 3      2020-01-25  Afghanistan          0          0       0
# 4      2020-01-26  Afghanistan          0          0       0
# ...           ...          ...        ...        ...     ...
# 76812  2020-05-09       Kosovo        862        622      28
# 76813  2020-05-10       Kosovo        870        653      28
# 76814  2020-05-11       Kosovo        884        655      28
# 76815  2020-05-12       Kosovo        895        657      28
# 76816  2020-05-13       Kosovo        919        671      29
#
# [76817 rows x 5 columns]

# %%
countries_refren = countries_ref.iloc[20:].rename(columns={"Country_Region": "Country"})

# %%
countries_covid_sampleNew = countries_covid_sample.merge(countries_refren, how="inner")
countries_covid_sampleNew
# Out:
#               Date    Country  Confirmed  Recovered  Deaths   UID iso2 iso3  \
# 0       2020-01-22  Australia          0          0       0    36   AU  AUS
# 1       2020-01-22  Australia          0          0       0  3601   AU  AUS
# 2       2020-01-22  Australia          0          0       0  3602   AU  AUS
# 3       2020-01-22  Australia          0          0       0  3603   AU  AUS
# 4       2020-01-22  Australia          0          0       0  3604   AU  AUS
# ...            ...        ...        ...        ...     ...   ...  ...  ...
# 293868  2020-05-09     Kosovo        862        622      28   383   XK  XKS
# 293869  2020-05-10     Kosovo        870        653      28   383   XK  XKS
# 293870  2020-05-11     Kosovo        884        655      28   383   XK  XKS
# 293871  2020-05-12     Kosovo        895        657      28   383   XK  XKS
# 293872  2020-05-13     Kosovo        919        671      29   383   XK  XKS
#
# ...

# %%
countries_covid_sampleNewL = countries_covid_sample.merge(countries_refren, how="left")
countries_covid_sampleNewL
# Out:
#               Date      Country  Confirmed  Recovered  Deaths    UID iso2  \
# 0       2020-01-22  Afghanistan          0          0       0    NaN  NaN
# 1       2020-01-23  Afghanistan          0          0       0    NaN  NaN
# 2       2020-01-24  Afghanistan          0          0       0    NaN  NaN
# 3       2020-01-25  Afghanistan          0          0       0    NaN  NaN
# 4       2020-01-26  Afghanistan          0          0       0    NaN  NaN
# ...            ...          ...        ...        ...     ...    ...  ...
# 306924  2020-05-09       Kosovo        862        622      28  383.0   XK
# 306925  2020-05-10       Kosovo        870        653      28  383.0   XK
# 306926  2020-05-11       Kosovo        884        655      28  383.0   XK
# 306927  2020-05-12       Kosovo        895        657      28  383.0   XK
# 306928  2020-05-13       Kosovo        919        671      29  383.0   XK
#
#        iso3  code3  FIPS Admin2 Province_State        Lat      Long_  \
# ...

# %%
countries_covid_sampleNewR = countries_covid_sample.merge(countries_refren, how="right")
countries_covid_sampleNewR
# Out:
#               Date  Country  Confirmed  Recovered  Deaths       UID iso2 iso3  \
# 0       2020-01-22  Belgium        0.0        0.0     0.0      5604   BE  BEL
# 1       2020-01-23  Belgium        0.0        0.0     0.0      5604   BE  BEL
# 2       2020-01-24  Belgium        0.0        0.0     0.0      5604   BE  BEL
# 3       2020-01-25  Belgium        0.0        0.0     0.0      5604   BE  BEL
# 4       2020-01-26  Belgium        0.0        0.0     0.0      5604   BE  BEL
# ...            ...      ...        ...        ...     ...       ...  ...  ...
# 297803         NaN       US        NaN        NaN     NaN  84056037   US  USA
# 297804         NaN       US        NaN        NaN     NaN  84056039   US  USA
# 297805         NaN       US        NaN        NaN     NaN  84056041   US  USA
# 297806         NaN       US        NaN        NaN     NaN  84056043   US  USA
# 297807         NaN       US        NaN        NaN     NaN  84056045   US  USA
#
# ...

# %%
countries_covid_sampleNewO = countries_covid_sample.merge(countries_refren, how="outer")
countries_covid_sampleNewO
# Out:
#               Date               Country  Confirmed  Recovered  Deaths  \
# 0       2020-01-22           Afghanistan        0.0        0.0     0.0
# 1       2020-01-23           Afghanistan        0.0        0.0     0.0
# 2       2020-01-24           Afghanistan        0.0        0.0     0.0
# 3       2020-01-25           Afghanistan        0.0        0.0     0.0
# 4       2020-01-26           Afghanistan        0.0        0.0     0.0
# ...            ...                   ...        ...        ...     ...
# 310859         NaN        Western Sahara        NaN        NaN     NaN
# 310860         NaN  Winter Olympics 2022        NaN        NaN     NaN
# 310861         NaN                 Yemen        NaN        NaN     NaN
# 310862         NaN                Zambia        NaN        NaN     NaN
# 310863         NaN              Zimbabwe        NaN        NaN     NaN
#
#            UID iso2 iso3  code3  FIPS Admin2 Province_State        Lat  \
# ...

# %%
countries_covid_sampleNewA = countries_covid_sample.merge(countries_refren, how="left_anti")
countries_covid_sampleNewA
# Out:
#              Date      Country  Confirmed  Recovered  Deaths  UID iso2 iso3  \
# 0      2020-01-22  Afghanistan          0          0       0  NaN  NaN  NaN
# 1      2020-01-23  Afghanistan          0          0       0  NaN  NaN  NaN
# 2      2020-01-24  Afghanistan          0          0       0  NaN  NaN  NaN
# 3      2020-01-25  Afghanistan          0          0       0  NaN  NaN  NaN
# 4      2020-01-26  Afghanistan          0          0       0  NaN  NaN  NaN
# ...           ...          ...        ...        ...     ...  ...  ...  ...
# 20395  2022-04-12      Belarus     970750          0    6882  NaN  NaN  NaN
# 20396  2022-04-13      Belarus     971649          0    6885  NaN  NaN  NaN
# 20397  2022-04-14      Belarus     972448          0    6889  NaN  NaN  NaN
# 20398  2022-04-15      Belarus     973206          0    6894  NaN  NaN  NaN
# 20399  2022-04-16      Belarus     974046          0    6899  NaN  NaN  NaN
#
# ...
